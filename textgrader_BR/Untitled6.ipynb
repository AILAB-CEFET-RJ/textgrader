# %%
pip install cogroo4py
# Out:
# ...
#      ---------------------------------------- 0.0/32.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/32.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/32.7 MB ? eta -:--:--
#      --------------------------------------- 0.0/32.7 MB 660.6 kB/s eta 0:00:50
#      --------------------------------------- 0.1/32.7 MB 975.2 kB/s eta 0:00:34
#      ---------------------------------------- 0.2/32.7 MB 1.5 MB/s eta 0:00:23
#       --------------------------------------- 0.5/32.7 MB 2.6 MB/s eta 0:00:13
#      - -------------------------------------- 0.9/32.7 MB 4.2 MB/s eta 0:00:08
#      -- ------------------------------------- 1.7/32.7 MB 6.4 MB/s eta 0:00:05
#      -- ------------------------------------- 2.4/32.7 MB 7.5 MB/s eta 0:00:05
#      --- ------------------------------------ 3.1/32.7 MB 9.0 MB/s eta 0:00:04
#      ---- ----------------------------------- 4.0/32.7 MB 10.1 MB/s eta 0:00:03
# ...

# %%
from cogroo4py.cogroo import Cogroo
cogroo = Cogroo()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 from cogroo4py.cogroo import Cogroo                                                          │
# │   2 cogroo = Cogroo()                                                                            │
# │   3                                                                                              │
# │                                                                                                  │
# │ C:\Users\ramon.boucas\.conda\envs\my_env\lib\site-packages\cogroo4py\cogroo.py:14 in <module>    │
# │                                                                                                  │
# ...
