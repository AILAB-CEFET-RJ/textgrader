# %%
from nltk import word_tokenize

# %%
def word_count(x):
    lista = word_tokenize(x)
    return len(lista)

# %%
def word_count_unique(x):
    lista = word_tokenize(x)
    return len(lista.unique())

# %%
import pandas as pd
df = pd.read_parquet('corrected_texts.parquet')

df['Essay Text'].apply(lambda x: word_count(x))
# Out:
# 0        58
# 1        54
# 2        39
# 3        18
# 4        33
#          ..
# 17202     1
# 17203     1
# 17204     1
# 17205     1
# 17206     1
# Name: new_text, Length: 17207, dtype: int64

# %%
df
# Out:
#           Id  EssaySet                                          EssayText  \
# 0          1         1  Some additional information that we would need...
# 1          2         1  After reading the expirement, I realized that ...
# 2          3         1  What you need is more trials, a control set up...
# 3          4         1  The student should list what rock is better an...
# 4          5         1  For the students to be able to make a replicat...
# ...      ...       ...                                                ...
# 17202  27584        10  white :: white becuase if you live in a hot pl...
# 17203  27585        10  light gray :: This color will affect the dogho...
# 17204  27586        10  light gray :: i think light gray would work th...
# 17205  27587        10  dark gray ::  if they painted the doghouse dar...
# 17206  27588        10  white :: the black would affect the doghouse b...
#
#        Score1  Score2                                           new_text
# 0           1       1   Some additional information that we would nee...
# 1           1       1   After reading the experiment, I realized that...
# 2           1       1   What you need is more trials, a control set u...
# 3           0       0   The student should list what rock is better a...
# 4           2       2   For the students to be able to make a replica...
# ...       ...     ...                                                ...
# 17202       1       1                                                  -
# 17203       1       1                                                  -
# 17204       1       1                                                  -
# 17205       1       0                                                  -
# 17206       0       1                                                  -
#
# [17207 rows x 6 columns]
